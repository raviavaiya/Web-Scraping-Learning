# %%
import requests
from bs4 import BeautifulSoup

web = requests.get("https://raviavaiya-portfolio.vercel.app/")
print(web)
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n  <meta charset="utf-8">\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">\n\n  <title>Ravi Avaiya | Portfolio</title>\n\n\n\n  <!-- Seo Details  -->\n\n  <meta name="author" content="Ravi Avaiya">\n  <meta name="robots" content="index, follow">\n  <meta property="og:url" content="https://raviavaiya-portfolio.netlify.app/">\n  <link rel="canonical" href="https://raviavaiya-portfolio.netlify.app/">\n  <meta property="og:title" content="ravi Avaiya | Portfolio">\n  <meta property="og:image" content="assets/img/hero-bg.jpg">\n  <meta property="og:description"\n    content="Ravi Avaiya - Web Developer | Crafting innovative web solutions tailored to your needs. Expert in Web Development.">\n  <meta property="og:type" content="website">\n  <meta property="og:locale" content="en_IN">\n  <link rel="manifest" href="/manifest.json">\n  <meta name="google-site-verification" content="w9idFm6Sm
# ...

# %%
web.url
# Out:
# 'https://raviavaiya-portfolio.vercel.app/'

# %%
web.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <title>
#    Ravi Avaiya | Portfolio
#   </title>
#   <!-- Seo Details  -->
#   <meta content="Ravi Avaiya" name="author"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="https://raviavaiya-portfolio.netlify.app/" property="og:url"/>
#   <link href="https://raviavaiya-portfolio.netlify.app/" rel="canonical"/>
#   <meta content="ravi Avaiya | Portfolio" property="og:title"/>
#   <meta content="assets/img/hero-bg.jpg" property="og:image"/>
#   <meta content="Ravi Avaiya - Web Developer | Crafting innovative web solutions tailored to your needs. Expert in Web Development." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="en_IN" property="og:locale"/>
#   <link href="/manifest.json" rel="manifest"/>
# ...

# %%
soup.title
# Out:
# <title>Ravi Avaiya | Portfolio</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.p
# Out:
# <p>Passionate Web Developer Crafting Engaging Digital Experiences</p>
